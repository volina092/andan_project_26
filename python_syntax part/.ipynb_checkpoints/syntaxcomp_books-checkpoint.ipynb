# %% [markdown]
# ### Синтаксические метрики для корпуса книг (syntaxcomp)
#
# Эта тетрадка:
#
# - берёт тексты книг из `books_clean/` по `corpus_metadata.csv`
# - размечает их **UDPipe** (CoNLL-U) через публичный API UFAL
# - считает синтаксические метрики библиотекой [`syntaxcomp`](https://pypi.org/project/syntaxcomp/)
# - сохраняет кэш разметки `.conllu` и итоговую таблицу `.csv`
#
# Важно:
#
# - `syntaxcomp` гарантирует корректность в первую очередь для разметки **UDPipe 2.12**.
# - Есть предупреждение о баге в извлечении **T-unit**. Поэтому метрики, завязанные на T-unit (`num_tu`, `mtl`, `cpt`), внизу можно автоматически исключить из финального датасета.

# %%
from __future__ import annotations

from pathlib import Path

# Корень репозитория (тетрадка лежит в python_syntax part/)
ROOT = Path.cwd().resolve().parent

DATA_DIR = ROOT / "books_dontsova_full_clean"
# DATA_DIR = ROOT / "books_clean"
META_CSV = ROOT / "corpus_metadata_dontsova_full.csv"
# META_CSV = ROOT / "corpus_metadata.csv"

CACHE_DIR = ROOT / "python_syntax part" / "dontsova_full_cache_conllu_udpipe"
# CACHE_DIR = ROOT / "python_syntax part" / "cache_conllu_udpipe"
OUT_DIR = ROOT / "python_syntax part" / "dontsova_full_output"
# OUT_DIR = ROOT / "python_syntax part" / "output"

CACHE_DIR.mkdir(parents=True, exist_ok=True)
OUT_DIR.mkdir(parents=True, exist_ok=True)

ROOT, DATA_DIR, META_CSV, CACHE_DIR, OUT_DIR
# Out:
# (WindowsPath('C:/Users/Маша/maga/andan_project_26'),
#  WindowsPath('C:/Users/Маша/maga/andan_project_26/books_dontsova_full_clean'),
#  WindowsPath('C:/Users/Маша/maga/andan_project_26/corpus_metadata_dontsova_full.csv'),
#  WindowsPath('C:/Users/Маша/maga/andan_project_26/python_syntax part/dontsova_full_cache_conllu_udpipe'),
#  WindowsPath('C:/Users/Маша/maga/andan_project_26/python_syntax part/dontsova_full_output'))

# %%
# Если запускаете впервые, раскомментируйте установку.
# (В идеале — в отдельном venv.)

# %pip install -q syntaxcomp conllu textdistance pandas requests tqdm

# %%
import json
import time
from dataclasses import dataclass

import pandas as pd
import requests
from tqdm.auto import tqdm

from syntaxcomp.complexity import TextComplexity

# %%
import hashlib
import random
import re
from typing import Iterable

UDPIPE_API = "https://lindat.mff.cuni.cz/services/udpipe/api"
UDPIPE_MODELS_URL = f"{UDPIPE_API}/models"
UDPIPE_PROCESS_URL = f"{UDPIPE_API}/process"

PREFER_UD_VERSION = "ud-2.12"  # syntaxcomp советует UDPipe 2.12

# Практика показывает, что для длинных художественных текстов лучше меньше чанки,
# иначе сервис иногда закрывает соединение без ответа.
MAX_CHUNK_CHARS = 10_000
REQUEST_TIMEOUT_S = 180

# Пауза между обычными запросами
SLEEP_BETWEEN_REQUESTS_S = 0.4

# Ретраи при сетевых сбоях/перегрузке сервиса
UDPIPE_MAX_RETRIES = 6
UDPIPE_BACKOFF_BASE_S = 1.0
UDPIPE_BACKOFF_MAX_S = 40.0
UDPIPE_BACKOFF_JITTER_S = 0.25

FORCE_REPARSE = False  # True => пересоздать весь кэш даже если файлы есть

DROP_TUNIT_METRICS = True  # из-за известного бага T-unit extraction в syntaxcomp

print("UDPipe:", UDPIPE_PROCESS_URL)
# Out:
# UDPipe: https://lindat.mff.cuni.cz/services/udpipe/api/process

# %%
def load_metadata() -> pd.DataFrame:
    df = pd.read_csv(META_CSV, encoding="utf-8")
    # Чистим возможный BOM (у тебя в скриптах было utf-8-sig)
    if df.columns[0].startswith("\ufeff"):
        df = df.rename(columns={df.columns[0]: df.columns[0].replace("\ufeff", "")})
    return df


def book_txt_path(row: pd.Series) -> Path:
    # Берём чистые книги (не токены/леммы), чтобы UDPipe видел пунктуацию.
    return DATA_DIR / row["series_slug"] / row["имя_файла"]


def cache_conllu_path(row: pd.Series, model_id: str) -> Path:
    # Чтобы кэш был воспроизводимым при смене модели, включаем model_id в имя.
    safe_model = re.sub(r"[^A-Za-z0-9_.-]+", "_", model_id)
    return CACHE_DIR / f"{row['series_slug']}__{row['имя_файла']}.{safe_model}.conllu"


def cache_meta_path(conllu_path: Path) -> Path:
    return conllu_path.with_suffix(conllu_path.suffix + ".json")


meta_df = load_metadata()
# meta_df.head(100)
len(meta_df)
# Out:
# 284

# %%
r = requests.get(UDPIPE_MODELS_URL, timeout=REQUEST_TIMEOUT_S)
r.raise_for_status()
payload = r.json()
models = payload.get("models", {})

lang_lower = LANGUAGE.lower()
candidates = [m for m in models.keys() if m.lower().startswith('russian') and PREFER_UD_VERSION in m.lower()]

# %%
print('\n'.join(candidates))
# Out:
# russian-syntagrus-ud-2.12-230717
# russian-gsd-ud-2.12-230717
# russian-taiga-ud-2.12-230717

# %%
UDPIPE_MODEL = "russian-syntagrus-ud-2.12-230717" # обучен на художественных текстах, поэтому выбираем его

# %%
def chunk_text(text: str, max_chars: int = MAX_CHUNK_CHARS) -> list[str]:
    """Режет текст на куски, чтобы UDPipe принимал запросы. Режет по пустым строкам/абзацам.
    """
    text = text.replace("\r\n", "\n").replace("\r", "\n")
    blocks = [b.strip() for b in re.split(r"\n\s*\n", text) if b.strip()]

    chunks: list[str] = []
    buf = ""

    # добавляет чанк с саиску и очищает buf
    def flush():
        nonlocal buf
        if buf.strip():
            chunks.append(buf.strip())
        buf = ""

    for block in blocks:
        if len(block) > max_chars:
            flush()
            lines = [ln.strip() for ln in block.split("\n") if ln.strip()]
            part = ""
            for ln in lines:
                if len(part) + 1 + len(ln) > max_chars:
                    if part.strip():
                        chunks.append(part.strip())
                    part = ln
                else:
                    part = (part + "\n" + ln).strip() if part else ln
            if part.strip():
                chunks.append(part.strip())
            continue

        if not buf:
            buf = block
        elif len(buf) + 2 + len(block) <= max_chars:
            buf = buf + "\n\n" + block
        else:
            flush()
            buf = block

    flush()
    return chunks

# %%
_session = requests.Session()


def _sleep_backoff(attempt: int) -> None:
    backoff = min(UDPIPE_BACKOFF_MAX_S, UDPIPE_BACKOFF_BASE_S * (2**attempt))
    backoff += random.random() * UDPIPE_BACKOFF_JITTER_S
    time.sleep(backoff)


def udpipe_process(text: str, model: str = UDPIPE_MODEL) -> str:
    """Возвращает CoNLL-U разметку для plain text.

    UDPipe иногда рвёт соединение без ответа (RemoteDisconnected). Поэтому тут есть ретраи.
    """
    data = {
        "model": model,
        "tokenizer": "",
        "tagger": "",
        "parser": "",
        "data": text,
        "output": "conllu",
    }

    last_err: Exception | None = None
    for attempt in range(UDPIPE_MAX_RETRIES + 1):
        try:
            r = _session.post(UDPIPE_PROCESS_URL, data=data, timeout=REQUEST_TIMEOUT_S)

            # 429/5xx — часто временная перегрузка; попробуем повторить
            if r.status_code in {429, 502, 503, 504}:
                last_err = requests.HTTPError(f"HTTP {r.status_code}: {r.text[:200]}")
                if attempt < UDPIPE_MAX_RETRIES:
                    _sleep_backoff(attempt)
                    continue
                raise last_err

            r.raise_for_status()
            payload = r.json()
            if "result" not in payload:
                raise RuntimeError(
                    f"UDPipe response has no 'result': {list(payload.keys())}"
                )
            return payload["result"]

        except (requests.exceptions.ConnectionError, requests.exceptions.Timeout, ValueError) as e:
            last_err = e
            if attempt < UDPIPE_MAX_RETRIES:
                _sleep_backoff(attempt)
                continue
            raise

    assert last_err is not None
    raise last_err


def annotate_text_to_conllu(text: str, model: str = UDPIPE_MODEL) -> str:
    chunks = chunk_text(text)
    conllus: list[str] = []
    for ch in tqdm(chunks, desc="UDPipe chunks", leave=False):
        conllus.append(udpipe_process(ch, model=model).strip())
        time.sleep(SLEEP_BETWEEN_REQUESTS_S)
    return "\n\n".join([c for c in conllus if c]) + "\n"

# %%
def sha256_text(s: str) -> str:
    return hashlib.sha256(s.encode("utf-8")).hexdigest()

def annotate_book(row: pd.Series, model: str = UDPIPE_MODEL, force: bool = FORCE_REPARSE) -> Path:
    src = book_txt_path(row)
    print(src)
    text = src.read_text(encoding="utf-8")
    text_hash = sha256_text(text)

    conllu_path = cache_conllu_path(row, model_id=model)
    meta_path = cache_meta_path(conllu_path)

    if not force and conllu_path.exists() and meta_path.exists():
        try:
            old = json.loads(meta_path.read_text(encoding="utf-8"))
            if old.get("text_sha256") == text_hash and old.get("model") == model:
                return conllu_path
        except Exception:
            pass

    conllu = annotate_text_to_conllu(text, model=model)
    conllu_path.write_text(conllu, encoding="utf-8")
    meta_path.write_text(
        json.dumps(
            {
                "src": str(src.relative_to(ROOT)),
                "model": model,
                "text_sha256": text_hash,
                "created_at": time.strftime("%Y-%m-%d %H:%M:%S"),
            },
            ensure_ascii=False,
            indent=2,
        ),
        encoding="utf-8",
    )
    return conllu_path

# %%
from time import perf_counter
from conllu import parse

# Для целой книги lev_pos/lev_dep в syntaxcomp считаются как попарные расстояния
# между ВСЕМИ предложениями => O(n^2). Поэтому считаем Levenshtein на подвыборке.
LEV_SAMPLE_SENTENCES = 250  # 200-400 обычно достаточно; 0 => выключить lev_* (будут 0)


def compute_syntaxcomp_metrics_from_conllu(conllu_text: str) -> dict:
    sentences = parse(conllu_text)
    print(f"Sentences in conllu: {len(sentences)}")

    # Временно подменяем pairwise_levenshtein, чтобы не считать на всех парах.
    orig_pairwise = getattr(TextComplexity, "pairwise_levenshtein", None)

    def _pairwise_levenshtein_sample(chains):
        import random
        from itertools import combinations
        from textdistance import levenshtein

        if LEV_SAMPLE_SENTENCES and len(chains) > LEV_SAMPLE_SENTENCES:
            chains = random.sample(chains, LEV_SAMPLE_SENTENCES)
        elif not LEV_SAMPLE_SENTENCES:
            return []

        return [levenshtein.distance(a, b) for a, b in combinations(chains, 2)]

    if orig_pairwise is not None:
        TextComplexity.pairwise_levenshtein = staticmethod(_pairwise_levenshtein_sample)

    t0 = perf_counter()
    try:
        tc = TextComplexity(sentences)
        # В некоторых версиях syntaxcomp tc.info() только печатает и возвращает None.
        # Поэтому собираем метрики из атрибутов tc.
        metrics = {
            "Number of Sentences": getattr(tc, "num_s", None),
            "Number of Words": getattr(tc, "num_w", None),
            "Number of Clauses": getattr(tc, "num_cl", None),
            # "Number of T-Units": getattr(tc, "num_tu", None),
            "Mean Sentence Length": round(getattr(tc, "msl", 0.0), 2),
            "Mean Clause Length": round(getattr(tc, "mcl", 0.0), 2),
            # "Mean T-Unit Length": round(getattr(tc, "mtl", 0.0), 2),
            "Mean Number of Clauses per Sentence": round(getattr(tc, "cps", 0.0), 2),
            # "Mean Number of Clauses per T-Unit": round(getattr(tc, "cpt", 0.0), 2),
            "Mean Tree Depth": round(getattr(tc, "mtd", 0.0), 2),
            "Median Tree Depth": getattr(tc, "mdtd", None),
            "Minimum Tree Depth": getattr(tc, "mntd", None),
            "Maximum Tree Depth": getattr(tc, "mxtd", None),
            "Mean Dependency Distance": round(getattr(tc, "mdd", 0.0), 2),
            "Node-to-Terminal-Node Ratio": round(getattr(tc, "node_to_term", 0.0), 2),
            "Average Levenshtein Distance between POS": round(getattr(tc, "lev_pos", 0.0), 2),
            "Average Levenshtein Distance between deprel": round(getattr(tc, "lev_dep", 0.0), 2),
            "Average NP Length": round(getattr(tc, "avg_np_len", 0.0), 2),
            "Complex NP Ratio": round(getattr(tc, "comp_np_ratio", 0.0), 2),
            "Number of Combined Clauses": getattr(tc, "comb", None),
            "Number of Coordinate Clauses": getattr(tc, "coord", None),
            "Number of Subordinate Clauses": getattr(tc, "subord", None),
            "Coordinate to Combined Clause Ratio": round(getattr(tc, "coord_to_comb", 0.0), 2),
            "Subordinate to Combined Clause Ratio": round(getattr(tc, "subord_to_comb", 0.0), 2),
            "Coordinate to Subordinate Clause Ratio": round(getattr(tc, "coord_to_subord", 0.0), 2),
            "Coordinate Clause to Sentence Ratio": round(getattr(tc, "coord_to_sent", 0.0), 2),
            "Subordinate Clause to Sentence Ratio": round(getattr(tc, "subord_to_sent", 0.0), 2),
        }

        clause_pct = getattr(tc, "clause_percentage", None)
        if isinstance(clause_pct, dict):
            for rel, val in clause_pct.items():
                metrics[f"{rel}_ratio"] = val

    finally:
        if orig_pairwise is not None:
            TextComplexity.pairwise_levenshtein = orig_pairwise

    metrics["__compute_seconds__"] = round(perf_counter() - t0, 2)

    return metrics


# Smoke-test на одной книге (можно менять индекс)
row0 = meta_df.iloc[98]
conllu_path0 = annotate_book(row0)
conllu0 = conllu_path0.read_text(encoding="utf-8")
metrics0 = compute_syntaxcomp_metrics_from_conllu(conllu0)
list(metrics0.items())[:12]
# Out:
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Ночной клуб на Лысой горе.txt
# Sentences in conllu: 4348
# [('Number of Sentences', 4348),
#  ('Number of Words', 36774),
#  ('Number of Clauses', 9858),
#  ('Mean Sentence Length', 8.46),
#  ('Mean Clause Length', 3.73),
#  ('Mean Number of Clauses per Sentence', 2.27),
#  ('Mean Tree Depth', 3.81),
#  ('Median Tree Depth', 3.0),
#  ('Minimum Tree Depth', 2),
#  ('Maximum Tree Depth', 15),
#  ('Mean Dependency Distance', 2.68),
#  ('Node-to-Terminal-Node Ratio', 1.82)]

# %%
# conllu0

# %%
def compute_metrics_for_corpus(df: pd.DataFrame, model: str = UDPIPE_MODEL) -> pd.DataFrame:
    rows = []
    errors = []

    for _, r in tqdm(df.iterrows(), total=len(df), desc="Books"):
        try:
            conllu_path = annotate_book(r, model=model)
            conllu_text = conllu_path.read_text(encoding="utf-8")
            m = compute_syntaxcomp_metrics_from_conllu(conllu_text)

            out = {
                "автор": r["автор"],
                "название": r["название"],
                "серия": r["серия"],
                "год": int(r["год"]),
                "папка": r["series_slug"],
                "имя_файла": r["имя_файла"],
                "conllu_cache": str(conllu_path.relative_to(ROOT)),
                **m,
            }
            rows.append(out)
        except Exception as e:
            errors.append({"имя_файла": r.get("имя_файла"), "error": repr(e)})

    if errors:
        (OUT_DIR / "syntaxcomp_errors.json").write_text(
            json.dumps(errors, ensure_ascii=False, indent=2), encoding="utf-8"
        )
        print(f"Errors: {len(errors)} (см. {OUT_DIR / 'syntaxcomp_errors.json'})")

    return pd.DataFrame(rows)


# Запуск на всём корпусе (может занять время, особенно в первый раз)
df_metrics = compute_metrics_for_corpus(meta_df)
out_csv = OUT_DIR / "syntaxcomp_metrics.csv"
df_metrics.to_csv(out_csv, index=False, encoding="utf-8")
out_csv
# Out:
# Books:   0%|          | 0/284 [00:00<?, ?it/s]
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Алые паруса Синей бороды.txt
# Sentences in conllu: 4128
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Билет на ковер-вертолет.txt
# Sentences in conllu: 4298
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Бинокль для всевидящего ока.txt
# Sentences in conllu: 4555
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Блеск и нищета инстаграма.txt
# Sentences in conllu: 4528
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Буря в стакане беды.txt
# Sentences in conllu: 4806
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_В когтях у сказки.txt
# Sentences in conllu: 3969
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Вечный двигатель маразма.txt
# Sentences in conllu: 4610
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Вставная челюсть Щелкунчика.txt
# Sentences in conllu: 4033
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Гимназия неблагородных девиц.txt
# Sentences in conllu: 4563
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Главбух и полцарства в придачу.txt
# Sentences in conllu: 4008
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Горячая любовь снеговика.txt
# Sentences in conllu: 4383
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Дезертир из рая.txt
# Sentences in conllu: 4666
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Дьявол носит лапти.txt
# Sentences in conllu: 4041
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Завещание рождественской утки.txt
# Sentences in conllu: 3917
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Закон молодильного яблочка.txt
# Sentences in conllu: 4260
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Замок храпящей красавицы.txt
# Sentences in conllu: 3875
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Зимнее лето весны.txt
# Sentences in conllu: 4868
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Инкогнито с Бродвея.txt
# Sentences in conllu: 4194
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Каникулы в Простофилино.txt
# Sentences in conllu: 4427
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Кекс в большом городе.txt
# Sentences in conllu: 3663
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Кнопка управления мужем.txt
# Sentences in conllu: 3799
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Козлёнок Алёнушка.txt
# Sentences in conllu: 4524
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Концерт для колобка с оркестром.txt
# Sentences in conllu: 4041
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Край непуганых Буратино.txt
# Sentences in conllu: 4533
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Летучий самозванец.txt
# Sentences in conllu: 4150
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Лобстер для Емели.txt
# Sentences in conllu: 4512
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Любимые забавы папы Карло.txt
# Sentences in conllu: 4071
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Магия госпожи Метелицы.txt
# Sentences in conllu: 3583
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Микстура от косоглазия.txt
# Sentences in conllu: 4138
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Милашка на вираже.txt
# Sentences in conllu: 4651
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Монстры из хорошей семьи.txt
# Sentences in conllu: 4119
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Муму с аквалангом.txt
# Sentences in conllu: 4501
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Муха в самолете.txt
# Sentences in conllu: 3596
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Неудачная карьера мегеры.txt
# Sentences in conllu: 4367
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Ночной кошмар Железного Любовника.txt
# Sentences in conllu: 4085
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Приданое лохматой обезьяны.txt
# Sentences in conllu: 4567
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Путеводитель по Лукоморью.txt
# Sentences in conllu: 3834
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Скелет из пробирки.txt
# Sentences in conllu: 4160
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Страстная ночь в зоопарке.txt
# Sentences in conllu: 3837
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Стриптиз Жар-птицы.txt
# Sentences in conllu: 4496
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Торт от Ябеды-корябеды.txt
# Sentences in conllu: 4696
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Три желания женщины-мечты.txt
# Sentences in conllu: 3818
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Три мешка хитростей.txt
# Sentences in conllu: 3819
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Ужас на крыльях ночи.txt
# Sentences in conllu: 4096
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Урожай ядовитых ягодок.txt
# Sentences in conllu: 4047
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Фанатка голого короля.txt
# Sentences in conllu: 3949
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Фея с золотыми зубами.txt
# Sentences in conllu: 3891
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Филе из Золотого Петушка.txt
# Sentences in conllu: 3870
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Фокус-покус от Василисы Ужасной.txt
# Sentences in conllu: 4014
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Хеппи-энд для Дездемоны.txt
# Sentences in conllu: 4760
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Человек-невидимка в стразах.txt
# Sentences in conllu: 3867
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Черт из табакерки.txt
# Sentences in conllu: 4112
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Чудеса в кастрюльке.txt
# Sentences in conllu: 3969
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\viola\ВТ_Чудовище без красавицы.txt
# Sentences in conllu: 3591
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Аллергия на кота Базилио.txt
# Sentences in conllu: 4238
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Ананас на ёлке.txt
# Sentences in conllu: 4355
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Аполлон на миллион.txt
# Sentences in conllu: 4223
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Бассейн с крокодилами.txt
# Sentences in conllu: 4019
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Белый конь на принце.txt
# Sentences in conllu: 3810
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Бенефис мартовской кошки.txt
# Sentences in conllu: 3689
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Блоха на балу.txt
# Sentences in conllu: 4441
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Вакантное место райской птички.txt
# Sentences in conllu: 4545
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Вынос дела.txt
# Sentences in conllu: 3916
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Гарпия с пропеллером.txt
# Sentences in conllu: 3704
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Гений страшной красоты.txt
# Sentences in conllu: 3992
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Годовой абонемент на тот свет.txt
# Sentences in conllu: 4920
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Дама с коготками.txt
# Sentences in conllu: 3900
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Дантисты тоже плачут.txt
# Sentences in conllu: 4152
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Дневник пакостей Снежинки.txt
# Sentences in conllu: 4863
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Доллары царя Гороха.txt
# Sentences in conllu: 4075
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Домик тетушки лжи.txt
# Sentences in conllu: 3755
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Досье на Крошку Че.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3945
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Другая жизнь оборотня.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4198
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Жаба с кошельком.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 3852
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Жена моего мужа.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_За всеми зайцами.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 3902
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Змеиный гаджет.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4758
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Игра в жмурики.txt
# UDPipe chunks:   0%|          | 0/24 [00:00<?, ?it/s]
# Sentences in conllu: 4148
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Ипотека на Марсе.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4372
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Кактус второй свежести.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4102
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Камин для Снегурочки.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4460
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Кекс от сапожника (в кн. Новогодний детектив 2015).txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 3846
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Коза и семеро волчат.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4175
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Компот из запретного плода.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3736
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Контрольный поцелуй.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3869
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Крутые наследнички.txt
# UDPipe chunks:   0%|          | 0/24 [00:00<?, ?it/s]
# Sentences in conllu: 4139
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Лебединое озеро Ихтиандра.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4301
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Легенда о трех мартышках.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3705
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Личное дело женщины-кошки.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4487
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Любовница египетской мумии.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3833
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Лягушка Баскервилей.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4331
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Медовое путешествие втроем.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 3670
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Метро до Африки.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4210
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Мокрое дело водяного.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4504
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Мыльная сказка Шахерезады.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4030
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Небо в рублях.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4360
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Несекретные материалы.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3741
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Ночной клуб на Лысой горе.txt
# Sentences in conllu: 4348
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Пальцы китайским веером.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 3901
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Пиявка голубых кровей.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4696
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Плохая репутация Курочки Рябы.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4385
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Полет над гнездом индюшки.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 3928
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Последняя гастроль госпожи Удачи.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4593
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Приват-танец мисс Марпл.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3958
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Привидение в кроссовках.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 3904
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Родословная до седьмого полена.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4257
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Ромео с большой дороги.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4607
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Самовар с шампанским.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4021
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Свидание под мантией.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4617
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Слон для Дюймовочки.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4349
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Сон дядюшки Фрейда.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4028
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Спят усталые игрушки.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4025
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Стилист для снежного человека.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4119
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Ступа с навигатором.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4461
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Темное прошлое Конька-Горбунка (сборник).txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3962
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Темные предки светлой детки.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4446
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Тормоза для блудного мужа.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3987
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Третий глаз — алмаз.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4491
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Улыбка 45-го калибра.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4258
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Уха из золотой рыбки.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3721
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Фейсконтроль на главную роль.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4342
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Хобби гадкого утенка.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3702
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Царевич с плохим резюме.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4333
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Шесть соток для Робинзона.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4024
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Штамп на сердце женщины-вамп.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4130
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Экстрим на сером волке.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4207
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\dasha\ДВ_Эта горькая сладкая месть.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4017
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Бабочка в гипсе.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3671
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Безумная кепка Мономаха.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 3754
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Белочка во сне и наяву.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3855
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Большой куш нищей герцогини.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4518
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Брачный контракт кентавра.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 3802
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Бутик ежовых рукавиц.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4487
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_В постели с Кинг-Конгом.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3803
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Вещие сны Храпунцель.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4651
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Витязь в розовых штанах.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4530
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Гадюка в сиропе.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3917
# Sentences in conllu: 4243
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Государыня Криворучка.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4345
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Девочка Красная Тапочка.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4434
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Добрый доктор Айбандит.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4043
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Жираф – гроза пингвинов.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4544
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Золушка в шоколаде.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4444
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Имидж напрокат.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4283
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Император деревни Гадюкино.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3727
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Камасутра для Микки-Мауса.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 3930
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Канкан на поминках.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3724
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Квазимодо на шпильках.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4003
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Королева без башни.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4427
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Коронная роль Козы-дерезы.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4167
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Корпоратив королевской династии.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 3996
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Коррида на раздевание.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4850
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Костюм Адама для Евы.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3650
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Кружок экстремального вязания.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4467
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Лампа разыскивает Алладина.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4203
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Леди Несовершенство.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4699
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Любовь-морковь и третий лишний.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3690
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Малютка Интрига.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4488
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Мамаша Бармалей.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4104
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Маникюр для покойника.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3698
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Маскарад любовных утех.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4074
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Матрешка в перьях.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3986
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Нежный супруг олигарха.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4332
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Но-шпа на троих.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 3995
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Ночная жизнь моей свекрови.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3986
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Обед у людоеда.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3748
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Огнетушитель Прометея.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 3957
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Ошибка Девочки-с-пальчик.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4774
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Покер с акулой.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3543
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Принцесса на Кириешках.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 3993
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Прогноз гадостей на завтра.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3701
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Пряник с черной икрой.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4397
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Пятизвездочный теремок.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4567
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Сволочь ненаглядная.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3835
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Синий мопс счастья.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4071
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Созвездие жадных псов.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3929
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Такси до леса Берендея.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4349
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Фанера Милосская.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4449
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Фиговый листочек от кутюр.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 3806
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Фигура легкого эпатажа.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4077
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Фэн-шуй без тормозов.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4788
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Хождение под мухой.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4109
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Хорошие манеры Соловья-разбойника.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4517
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Черный список деда Мазая.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3961
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Чудо-юдо на охоте.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4489
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Шопинг в воздушном замке.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4407
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\evlampia\ЕР_Шуры-муры с призраком.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 3955
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_13 несчастий Геракла.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4043
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Авоська с Алмазным фондом.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 3766
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Али-Баба и сорок разбойниц.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 3842
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Ангел на метле.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4122
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Архитектор пряничного домика.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4375
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Астральное тело холостяка.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4122
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Бабулька на горошине.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4083
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Блог проказника домового.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4434
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Бриллиант мутной воды.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3762
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Букет прекрасных дам.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3849
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Венец безбрачия белого кролика.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4893
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Венок из железных одуванчиков.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4377
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Верхом на «Титанике».txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4351
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Глазастая, ушастая беда.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4428
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Гнездо перелетного сфинкса.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4265
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Гризли в белых носочках.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4033
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Две невесты на одно место.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3648
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Дерзкие надежды Карабаса-Барабаса.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4292
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Иван Грозный на Мальдивах.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4528
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Иванушка на курьих ножках.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4445
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Инстинкт Бабы-Яги.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3803
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Кладбище чужих секретов.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4386
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Корона Мышки-норушки.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4258
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Коронный номер мистера Х.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4089
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Кто в чемодане живет.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4373
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Мачо чужой мечты.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3996
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Надувная женщина для Казановы.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4078
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Особа королевских ролей.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4288
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Пикник на острове сокровищ.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 3944
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Продюсер козьей морды.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4267
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Рыбка по имени Зайка.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 4373
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Сафари на черепашку.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3697
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Смех и грех Ивана-царевича.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3499
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Судьба найдет на сеновале.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 3650
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Тайная связь его величества.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 3879
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Тушканчик в бигудях.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4057
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Чучело от первого брака.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 3999
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\podushkin\ИП_Яблоко Монте-Кристо.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# Sentences in conllu: 3925
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\kozlova\СК_Аукцион волшебного хлама.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4627
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\kozlova\СК_Бизнес-план трех богатырей.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4062
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\kozlova\СК_Вредная волшебная палочка.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4244
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\kozlova\СК_Голое платье звезды.txt
# UDPipe chunks:   0%|          | 0/25 [00:00<?, ?it/s]
# Sentences in conllu: 4099
# C:\Users\Маша\maga\andan_project_26\books_dontsova_full_clean\kozlova\СК_Дворец со съехавшей крышей.txt
# UDPipe chunks:   0%|          | 0/26 [00:00<?, ?it/s]
